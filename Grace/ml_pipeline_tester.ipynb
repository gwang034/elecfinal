# %%
import sys
GITHUB_PATH = '/Users/gracewang/Documents/GitHub/elecfinal'
sys.path.insert(0, GITHUB_PATH)

import pandas as pd
from ml_pipeline import clean_split

# %%
X_train, X_val, X_query, y_train, y_val, y_query = clean_split("/Users/gracewang/Documents/GitHub/elecfinal/Data/train_data.csv", "/Users/gracewang/Documents/GitHub/elecfinal/Data/feature_weights.csv",
            "/Users/gracewang/Documents/GitHub/elecfinal/Data/morph_embeddings.csv")
# Out:
# 77
# 77
# 31
# 16

# %%
X_query
# Out:
#             ID  adp_dist  post_skeletal_distance_to_soma  \
# 33119    75712 -0.166175                       -0.115493
# 33120    75713 -1.329003                       -0.911014
# 33121    75714 -0.980492                       -0.333390
# 33122    75715 -0.591953                       -0.675306
# 33123    75716  0.797145                       -0.420162
# ...        ...       ...                             ...
# 179187  221780 -1.029047                        0.219202
# 179188  221781 -0.987628                       -0.855499
# 179189  221782 -0.123193                        1.371097
# 179190  221783  0.962485                       -0.099739
# 179191  221784  1.461853                       -0.803385
#
#         pre_skeletal_distance_to_soma  pre_oracle  pre_test_score  \
# 33119                       -1.770913   -0.106700       -0.457674
# 33120                       -1.528620   -0.106700       -0.457674
# 33121                       -1.379599   -0.106700       -0.457674
# ...
